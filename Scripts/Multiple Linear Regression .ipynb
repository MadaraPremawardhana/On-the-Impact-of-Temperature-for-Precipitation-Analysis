# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# %%
df = pd.read_csv(r'C:\Users\madara.premawardhana\Documents\UniversityCollegeDublin\QuickResearch\Datasets\West_australia.csv')
df = df.dropna(axis="rows", how="any")
df= df[df['rainfall_mm'] != 0]
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MADARA~1.PRE\AppData\Local\Temp/ipykernel_101760/2401126051.py in <module>
# ----> 1 df = pd.read_csv(r'C:\Users\madara.premawardhana\Documents\UniversityCollegeDublin\QuickResearch\Datasets\West_australia.csv')
#       2 df = df.dropna(axis="rows", how="any")
#       3 df= df[df['rainfall_mm'] != 0]
#       4 df
#
# NameError: name 'pd' is not defined

# %%
x = df.drop(['rainfall_mm'], axis = 1).values
y = df['rainfall_mm'].values
print(x)
print(y)
# Out:
# [[10.3  22.1  16.2  11.8  25.4 ]
#  [20.1  30.5  25.3  10.4   7.5 ]
#  [20.2  31.9  26.05 11.7  31.  ]
#  ...
#  [17.8  24.7  21.25  6.9  18.4 ]
#  [16.3  23.2  19.75  6.9  26.8 ]
#  [ 8.9  23.5  16.2  14.6  30.3 ]]
# [3.6 2.  1.4 ... 7.  0.4 0.6]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size = 0.3, random_state=0)

# %%
ml=LinearRegression()
ml.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=ml.predict(x_test)
print(y_pred)
# Out:
# [ 6.91794804 12.40115116  4.05818241  7.69753788  7.85046757 10.35369023
#   6.82341679  9.69490116  0.31453007  7.57546757  6.76843632  7.82185429
#   9.71726445  9.33161991  6.59089726  8.81951054  7.94128788  8.79656132
#   8.20232304  4.8845496  -0.46838009  5.6102332  12.75691288  1.7617957
#  13.27019413  8.0642371   9.01228398  7.90837773 11.93738163  7.78669804
#   5.98640507  8.49324101 10.16384648  8.75788945  3.39353398  2.04978398
#   7.6274207  10.49900273  2.01570195 10.15124882  8.75652226  5.08855351
#   6.98484257  4.39451054  4.0117957   9.45915898 -1.6435754   0.83122929
#   8.63845585 12.40828007 10.19890507  5.87439335  3.34343632  8.51775273
#  11.06658085  3.99792851  5.45935429  7.39490116  3.27175663  7.32859257
#   0.1086707   8.00583866  3.7305457   9.44265507  1.20603398  3.82566288
#   9.00886601  5.15681523  5.88816288  6.25632695 -3.16886837 11.58669804
#   9.18796757  3.09724491  5.25417851  8.54558476 10.43328007  7.47654179
# ...

# %%
ml.predict([[10.3,22.1,16.20,11.8,25.4]])
# Out:
# array([3.57370664])

# %%
r2_score(y_test,y_pred)
# Out:
# 0.06937098127950414

# %%
ax = plt.figure(figsize=(8,5))
plt.scatter(y_test,y_pred)
plt.xlabel('Actual', fontsize=20)
plt.ylabel('Predicted',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title('Predicting Rainfall from Weather Data - Alpena,USA',fontsize=18)
# Out:
# Text(0.5, 1.0, 'Predicting Rainfall from Weather Data - Alpena,USA')

# %%
pred_y_df = pd.DataFrame({'Actual Value':y_test,'Predictd Value':y_pred, 'Difference':y_test-y_pred})
pred_y_df[0:20]
# Out:
#     Actual Value  Predictd Value  Difference
# 0            0.8        6.917948   -6.117948
# 1            3.8       12.401151   -8.601151
# 2            0.8        4.058182   -3.258182
# 3            4.4        7.697538   -3.297538
# 4            1.4        7.850468   -6.450468
# 5           12.6       10.353690    2.246310
# 6            0.8        6.823417   -6.023417
# 7            5.8        9.694901   -3.894901
# 8            0.2        0.314530   -0.114530
# 9            2.2        7.575468   -5.375468
# 10          18.0        6.768436   11.231564
# 11           2.0        7.821854   -5.821854
# 12           4.6        9.717264   -5.117264
# 13          22.2        9.331620   12.868380
# 14           3.6        6.590897   -2.990897
# 15          31.8        8.819511   22.980489
# 16           4.4        7.941288   -3.541288
# 17          39.8        8.796561   31.003439
# 18          26.0        8.202323   17.797677
# 19           0.4        4.884550   -4.484550
