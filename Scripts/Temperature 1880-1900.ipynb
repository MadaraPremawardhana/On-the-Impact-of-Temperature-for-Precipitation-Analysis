# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
df = pd.read_csv(r'C:\Users\madara.premawardhana\Documents\UniversityCollegeDublin\QuickResearch\Datasets\data.csv')
print (df)
# Out:
#      Year  Value
# 0    1880  -0.13
# 1    1881  -0.09
# 2    1882  -0.10
# 3    1883  -0.19
# 4    1884  -0.27
# ..    ...    ...
# 135  2015   0.92
# 136  2016   0.99
# 137  2017   0.91
# 138  2018   0.82
# 139  2019   0.94
#
# [140 rows x 2 columns]

# %%
year = df.Year
temp = df.Value
plt.figure(figsize=(16,8))
plt.bar(year,temp)

plt.xlabel("Year",fontsize=18)
plt.ylabel("Temperature",color="black",fontsize=14)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.show()
plt.savefig('Average annual global temperatures.png')
